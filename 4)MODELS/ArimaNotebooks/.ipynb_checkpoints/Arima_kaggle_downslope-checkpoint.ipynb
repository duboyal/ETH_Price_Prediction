# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn; seaborn.set()
from sklearn.metrics import mean_squared_error
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# Any results you write to the current directory are saved as output.
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15,6
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.arima_model import ARIMA

# %%
df = pd.read_csv('EtherPriceHistory(USD).csv')

# %%
df[0:5]
# Out:
#    Date(UTC)  UnixTimeStamp  Value
# 0  7/30/2015     1438214400    0.0
# 1  7/31/2015     1438300800    0.0
# 2   8/1/2015     1438387200    0.0
# 3   8/2/2015     1438473600    0.0
# 4   8/3/2015     1438560000    0.0

# %%
#df = pd.read_csv('formatted_datetime_eth_pricedata.csv')
df = df[13:]

# %%
date = pd.to_datetime(df['Date(UTC)'])
price = df['Value']

# %%
type(date), type(price)
# Out:
# (pandas.core.series.Series, pandas.core.series.Series)

# %%
df['Date'] = pd.to_datetime(df['Date(UTC)'],infer_datetime_format=True)
date = df['Date']

# %%
price.index = date

# %%
len(date), len(price)
# Out:
# (956, 956)

# %%
price.index = date

# %%
from statsmodels.tsa.arima_model import ARIMA

# %% [markdown]
# ##### looking at price

# %%
price[0:5]
# Out:
# Date
# 2015-08-12    1.29
# 2015-08-13    1.88
# 2015-08-14    1.79
# 2015-08-15    1.79
# 2015-08-17    1.30
# Name: Value, dtype: float64

# %%
len(price)
# Out:
# 956

# %%
0.7*len(price)
# Out:
# 669.1999999999999

# %% [markdown]
# ### kaggle notebook

# %%
max(price)
# Out:
# 1385.02

# %%
stuff2 = price[price == max(price)]

# %%
stuff2
# Out:
# Date
# 2018-01-13    1385.02
# Name: Value, dtype: float64

# %%
price1 = price['2015-08-12':'2018-01-13']

# %%
price2 = price['2018-01-13':]

# %%
price2[-1]
# Out:
# 448.78

# %%
price[price == 448.78]
# Out:
# Date
# 2018-03-27    448.78
# Name: Value, dtype: float64

# %% [markdown]
# price1 and price 2 need to go through a test train split
#
# then we will make two models. one for each
#
# this will also have to be done on the differenced
# data due to stationarity

# %% [markdown]
# ### Now price 2, downslope

# %%
len(price1) #upsloope length
# Out:
# 883

# %%
len(price2) #downslope length
# Out:
# 74

# %% [markdown]
# ok we need to take price 1 and do a test train split

# %%
price2_train = price2[:56]

# %%
ts_logtransformed = np.log(price1_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-275c1b7fdb5b> in <module>()
# ----> 1 ts_logtransformed = np.log(price1_train)
#
# NameError: name 'price1_train' is not defined

# %%
price2_test = price2[56:]

# %%
len(price2_test)

# %%
price2[56]
# Out:
# 682.3

# %%
price2[price2 == 682.3]
# Out:
# Date
# 2018-03-10    682.3
# Name: Value, dtype: float64

# %%
plt.plot(price2_train)

# %%
ts_logtransformed = np.log(price2_train)
plt.plot(ts_logtransformed)

# %% [markdown]
# ### Rolling Mean

# %%
Rolling_average = ts_logtransformed.rolling(window = 7, center= False).mean()
plt.plot(ts_logtransformed, label = 'Log Transformed')
plt.plot(Rolling_average, color = 'red', label = 'Rolling Average')
plt.legend(loc = 'best')

# %%
log_Rolling_difference = ts_logtransformed - Rolling_average
log_Rolling_difference.head(10)
log_Rolling_difference.tail(10)
# Out:
# Date
# 2018-02-28    0.006492
# 2018-03-01    0.016699
# 2018-03-02    0.000008
# 2018-03-03   -0.003682
# 2018-03-04    0.002876
# 2018-03-05   -0.012075
# 2018-03-06   -0.043127
# 2018-03-07   -0.107665
# 2018-03-08   -0.148560
# 2018-03-09   -0.085867
# Name: Value, dtype: float64

# %%
#adfuller(log_Rolling_difference) #LinAlgError: SVD did not converge

# %%
stuff = ts_logtransformed - Rolling_average

# %%
#stuff #We see Nans in the begining

# %%
stuff.dropna(inplace=True)

# %%
#stuff # now they are gone

# %%
log_Rolling_difference.dropna(inplace=True) #very important because or else does not converge
plt.plot(log_Rolling_difference)

# %%
adfuller(log_Rolling_difference)
# Out:
# (-3.5131340387638694,
#  0.007656121925899306,
#  3,
#  46,
#  {'1%': -3.5812576580093696,
#   '10%': -2.6015409829867675,
#   '5%': -2.9267849124681518},
#  -115.49815201920495)

# %% [markdown]
# low p value!! good sign!

# %%
expwighted_avg = ts_logtransformed.ewm(halflife=7,min_periods=0,adjust=True,ignore_na=False).mean()
plt.plot(ts_logtransformed, label = 'Log transfomed')
plt.plot(expwighted_avg, color='red', label = 'exponential weighted average')
plt.legend(loc = 'best')

# %%
log_expmovwt_diff = ts_logtransformed - expwighted_avg

# %%
adfuller(log_expmovwt_diff)
# Out:
# (-3.3619147049887856,
#  0.012327773262907992,
#  3,
#  52,
#  {'1%': -3.562878534649522,
#   '10%': -2.597393446745562,
#   '5%': -2.918973284023669},
#  -127.97010055058439)

# %% [markdown]
# is a low p value !

# %% [markdown]
# ### Seasonality Adjustment by Differencing

# %%
ts_diff_logtrans = ts_logtransformed -ts_logtransformed.shift(7) #implies 7 days
plt.plot(ts_diff_logtrans)
ts_diff_logtrans.head(10) #thats why there are nans for first 7
# Out:
# Date
# 2018-01-13         NaN
# 2018-01-14         NaN
# 2018-01-15         NaN
# 2018-01-16         NaN
# 2018-01-17         NaN
# 2018-01-18         NaN
# 2018-01-19         NaN
# 2018-01-20   -0.185518
# 2018-01-21   -0.259179
# 2018-01-22   -0.246196
# Name: Value, dtype: float64

# %%
ts_diff_logtrans = ts_diff_logtrans[8:]
ts_diff_logtrans = ts_diff_logtrans.fillna(0)

# %%
adfuller(ts_diff_logtrans)
# Out:
# (-2.527576560199126,
#  0.10890799951581381,
#  7,
#  40,
#  {'1%': -3.6055648906249997, '10%': -2.606985625, '5%': -2.937069375},
#  -78.09620830763794)

# %% [markdown]
# this one not a low p value

# %% [markdown]
# ### decomposition

# %%
#done on log(price)
decomposition = seasonal_decompose(ts_logtransformed, freq=7) #seasonal period.

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid 
#im gonna break these up into 3 components
#take the original, subtract of trend subract off seasonal, 
#whatever is left is residual
#aka noise

plt.subplot(411)
plt.plot(ts_logtransformed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()
#then plotted, frist is original, second is trend, third is seanoality, 4th is residuals

# %%
#done on price data
decomposition = seasonal_decompose(price2_train, freq=7)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(ts_logtransformed, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
mega_diff_series = ts_logtransformed - Rolling_average - expwighted_avg - ts_logtransformed.shift(7)

# %%
#nans as expected.. thus
mega_diff_series = mega_diff_series[8:]

# %%
adfuller(mega_diff_series)
# Out:
# (-1.0625561233554934,
#  0.7297708639640333,
#  7,
#  40,
#  {'1%': -3.6055648906249997, '10%': -2.606985625, '5%': -2.937069375},
#  -77.69357678811386)

# %% [markdown]
# bad p-value... looks like the only good p-value is the rolling mean!

# %% [markdown]
# ### Forecasting

# %%
#ACF and PACF plots:
lag_acf = acf(log_Rolling_difference, nlags=10) #had to change these lag values because max lags compared to n obs
# originally had 30 for acf, and 50 for pacf
lag_pacf = pacf(log_Rolling_difference, nlags=30, method='ols')

# %%
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5,1,'Autocorrelation Function')

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
pyplot.figure()
pyplot.subplot(211)
plot_acf(log_Rolling_difference, ax=pyplot.gca(),lags=40)
pyplot.subplot(212)
plot_pacf(log_Rolling_difference, ax=pyplot.gca(), lags=50)
pyplot.show()

# %% [markdown]
# ### directly comparing  and applying the method and reasoning: from the kaggle bitcoin notebook, to ethereum data.
#
# Below are some observations from the plots.
#
# In this plot, the two dotted lines on either sides of 0 are the confidence interevals. (the blue region) These can be used to determine the ‘p’ and ‘q’ values as: the Lag values are identified from PACF and ACF plots for Autoregression(AR) and Moving Average(MA) parameters, p and q respectively p – The lag value where the PACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case p=3, The PACF shows a significant lag on day 2.
#
# q – The lag value where the ACF chart crosses the upper confidence interval for the first time. If you notice closely, in this case q=7,(q = 25 if we look at higher graph) since the ACF shows a significant lag for 7th day.

# %% [markdown]
# ### Do Dickey Fuller test for stationarity

# %% [markdown]
# 2nd value p-value is 0.75
# The null hypothesis of the Augmented Dickey-Fuller is that there is a unit root, with the alternative that there is no unit root. If the pvalue is above a critical size, then we cannot reject that there is a unit root.
# so in ur case ist > 0.05 so we cannot reject the null hypothesis
# which means ur series has a unit root
# now check https://en.wikipedia.org/wiki/Unit_root_test
# oh that means it is not stationary?
# ugh
# the gist is if ur series has a unit root its not statinary
# yeah 😐
# so doesnt matter what else you get
# because "A common assumption in many time series techniques is that the data are stationary. A stationary process has the property that the mean, variance and autocorrelation structure do not change over time"
# if this gets violated nothing else matters
#
# we need to use the stationary log transformed.
#
# yeah whichever series gives u a p-value (2nd value in that adfuller) < 0.05 -
# use that one and do everything on that -
# also the process we just followed, you can leverage that in the future for some function and to interpret its results esepcially if its a bit complex like this one -
# ok.. just wondering for when i do the predicting...what will i be predicting? -
# the price itself and u can match it with the log diff of the series
# u can get back the original price anyway after doing an inverse transform -
# so will i be predicting a new "log_diff_trans" and then reverse transforming that data to get price back? -
# yes but only if the series is stationary when you trained the model (after applying the transformations and doing the ad fuller test) -
# refer to https://machinelearningmastery.com/time-series-forecast-study-python-monthly-sales-french-champagne/ -
# in this case they do some seasonal differncing also to make it stationary so he mentions the same, "For reference, the seasonal difference operation can be inverted by adding the observation for the same month the year before. This is needed in the case that predictions are made by a model fit on seasonally differenced data. "

# %%
model = ARIMA(log_Rolling_difference, order=(3, 1, 2))  
results_ARIMA = model.fit(trend= 'nc', disp=-1)  
plt.plot(log_Rolling_difference)
plt.plot(results_ARIMA.fittedvalues, color='red', label = 'p =2, q =6')
RSS =results_ARIMA.fittedvalues-log_Rolling_difference
RSS.dropna(inplace=True)
plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc='best')
print('AIC:')
print(results_ARIMA.aic)
# Out:
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# AIC:
# -131.33700046640078

# %%
model = ARIMA(log_Rolling_difference, order=(3, 0, 2))  
results_ARIMA = model.fit(trend= 'nc', disp=-1)  
plt.plot(log_Rolling_difference)
plt.plot(results_ARIMA.fittedvalues, color='red', label = 'p =2, q =21')
RSS =results_ARIMA.fittedvalues-log_Rolling_difference
RSS.dropna(inplace=True)
plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc='best')
print('AIC:')
print(results_ARIMA.aic)
# Out:
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# AIC:
# -135.65227973368042

# %%
model = ARIMA(log_Rolling_difference, order=(2, 0, 3))  
results_ARIMA = model.fit(trend= 'nc', disp=-1)  
plt.plot(log_Rolling_difference)
plt.plot(results_ARIMA.fittedvalues, color='red', label = 'p =3, q =2')
RSS =results_ARIMA.fittedvalues-log_Rolling_difference
RSS.dropna(inplace=True)
plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc='best')
print('AIC:')
print(results_ARIMA.aic)
# Out:
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# AIC:
# -137.89956520652936

# %%
model = ARIMA(log_Rolling_difference, order=(3, 0, 3))  
results_ARIMA = model.fit(trend= 'nc', disp=-1)  
plt.plot(log_Rolling_difference)
plt.plot(results_ARIMA.fittedvalues, color='red', label = 'p =3, q =2')
RSS =results_ARIMA.fittedvalues-log_Rolling_difference
RSS.dropna(inplace=True)
plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc='best')
print('AIC:')
print(results_ARIMA.aic)
# Out:
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# AIC:
# -139.477841353357

# %% [markdown]
# interesting only q = 7 and q = 8 give us an AIC,the others are talking about MA not invertible,  and higher than 8 is non stationarity.

# %% [markdown]
# ### Testing out different parameters:
# note: done on tsdifflogtrans vs ts_logtransformed... ACF and PACF were done on diff, so it makes sense to train the model on diff

# %% [markdown]
# ### now predict price2:

# %%
print(price[700]) #this is the last index of price1
print(price[price == 224.15])
# Out:
# 224.15
# Date
# 2017-07-12    224.15
# Name: Value, dtype: float64

# %%
#what is the last date of test? March 27th
price2[price2 == 448.78]
# Out:
# Date
# 2018-03-27    448.78
# Name: Value, dtype: float64

# %%
#remember we took test and train up to the peak only... so 
#this makes sense 
#'2017-07-12' should be the last of the train, 
#first date should be inclusive not sure about last date...

results_ARIMA.predict(start='2018-03-10' , end='2018-03-27')
# Out:
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# 2018-03-10    0.000000
# 2018-03-11    0.072592
# 2018-03-12    0.134963
# 2018-03-13    0.102875
# 2018-03-14    0.101974
# 2018-03-15    0.016431
# 2018-03-16    0.019455
# 2018-03-17   -0.044250
# 2018-03-18   -0.073046
# 2018-03-19   -0.024794
# 2018-03-20    0.021601
# 2018-03-21    0.051196
# 2018-03-22    0.043783
# 2018-03-23    0.019644
# 2018-03-24    0.026246
# 2018-03-25   -0.003651
# 2018-03-26   -0.023604
# 2018-03-27   -0.045500
# Freq: D, dtype: float64

# %%
#price2_test = price2[(56-6):]

# %%
forecast = results_ARIMA.predict(start='2018-03-10' , end='2018-03-27')
#need to transform the test data with log and rolling mean!

ts_logtransformed_test = np.log(price2_test)
Rolling_average_test = ts_logtransformed_test.rolling(window = 7, center= False).mean()
tranformed_test = ts_logtransformed_test - Rolling_average_test

# ok we actually need to deal with these nans. 
# price2_test needs to go 7 back... to account for the gap
# thats why we did price2_test = price2[(56-6):]

plt.plot(forecast, color = 'green', label ='Predicted rates')
plt.plot(tranformed_test, color = 'red',label = 'Observed from test data')
plt.legend(loc='best')
# Out:
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %% [markdown]
# comparing to litalert's, she takes the Y value and trains on it the model with the ...
# ok what I'd have to do is tranform the bircoin data and put it in as an exo variable

# %% [markdown]
# # OK under this is all playing around

# %%
from cryptocmd import CmcScraper
scraper2 = CmcScraper('BTC', '10-03-2018', '27-3-2018')
headers, data = scraper2.get_data()
scraper2.export_csv()
df_b = pd.read_csv('BTC_10-03-2018_27-03-2018.csv', dtype=str)

# %%
def convert_date(date_string):
    nums = date_string.split('-')
    alt_format = '{}-{}-{}'.format(nums[1], nums[0], nums[2])
    #alt_format = datetime.datetime(int(nums[2]), int(nums[0]), int(nums[1]), 0, 0)
    return alt_format

# %%
df_b['Date'] = df_b['Date'].apply(convert_date)
df_b['Date'] = pd.to_datetime(df_b['Date'],infer_datetime_format=True)
df_b = df_b.sort_values('Date')

# %%
#price_b = df_b['Close']

# %%
#price_b.index = df_b['Date']

# %%
type(price_b)
# Out:
# pandas.core.series.Series

# %%
listcomp = [float(item) for item in price_b]

# %%
df_b['Close'] = listcomp

# %%
price_b = df_b['Close']

# %%
price_b.index = df_b['Date']

# %%
price_b
# Out:
# Date
# 2018-03-10    8866.00
# 2018-03-11    9578.63
# 2018-03-12    9205.12
# 2018-03-13    9194.85
# 2018-03-14    8269.81
# 2018-03-15    8300.86
# 2018-03-16    8338.35
# 2018-03-17    7916.88
# 2018-03-18    8223.68
# 2018-03-19    8630.65
# 2018-03-20    8913.47
# 2018-03-21    8929.28
# 2018-03-22    8728.47
# 2018-03-23    8879.62
# 2018-03-24    8668.12
# 2018-03-25    8495.78
# 2018-03-26    8209.40
# 2018-03-27    7833.04
# Name: Close, dtype: float64

# %%
ts_logtransformed_b = np.log(price_b)

# %%
type(price_b)
# Out:
# pandas.core.series.Series

# %%
Rolling_average = ts_logtransformed_b.rolling(window = 7, center= False).mean()
Rolling_average.fillna(0)
plt.plot(ts_logtransformed_b, label = 'Log Transformed')
plt.plot(Rolling_average, color = 'red', label = 'Rolling Average')
plt.legend(loc = 'best')

# %%
Rolling_average.fillna(9.0) #ugh doesnt work
# Out:
# Date
# 2018-03-10    0.000000
# 2018-03-11    0.000000
# 2018-03-12    0.000000
# 2018-03-13    0.000000
# 2018-03-14    0.000000
# 2018-03-15    0.000000
# 2018-03-16    9.083469
# 2018-03-17    9.067294
# 2018-03-18    9.045506
# 2018-03-19    9.036300
# 2018-03-20    9.031860
# 2018-03-21    9.042821
# 2018-03-22    9.049997
# 2018-03-23    9.058981
# 2018-03-24    9.071932
# 2018-03-25    9.076582
# 2018-03-26    9.069434
# 2018-03-27    9.050975
# Name: Close, dtype: float64

# %%
#omg... anyway just hard coding to see something
Rolling_average['2018-03-10 '] = 9
Rolling_average['2018-03-11 '] = 9
Rolling_average['2018-03-12 '] = 9
Rolling_average['2018-03-13 '] = 9
Rolling_average['2018-03-14 '] = 9
Rolling_average['2018-03-15 '] = 9

# %%
plt.plot(ts_logtransformed_b, label = 'Log Transformed')
plt.plot(Rolling_average, color = 'red', label = 'Rolling Average')
plt.legend(loc = 'best')

# %%
log_Rolling_difference_b = ts_logtransformed_b - Rolling_average

# %%
#ACF and PACF plots:
lag_acf = acf(log_Rolling_difference_b, nlags=2) #had to change these lag values because max lags compared to n obs
# originally had 30 for acf, and 50 for pacf
lag_pacf = pacf(log_Rolling_difference_b, nlags=5, method='ols')

# %%
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5,1,'Autocorrelation Function')

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(log_Rolling_difference)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
pyplot.figure()
pyplot.subplot(211)
plot_acf(log_Rolling_difference, ax=pyplot.gca(),lags=40)
pyplot.subplot(212)
plot_pacf(log_Rolling_difference, ax=pyplot.gca(), lags=50)
pyplot.show()

# %%
model = ARIMA(log_Rolling_difference_b, order=(2, 0, 0))  
results_ARIMA = model.fit(trend= 'nc', disp=-1)  
plt.plot(log_Rolling_difference_b)
plt.plot(results_ARIMA.fittedvalues, color='red', label = 'p =2, q =6')
RSS =results_ARIMA.fittedvalues-log_Rolling_difference
RSS.dropna(inplace=True)
plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc='best')
print('AIC:')
print(results_ARIMA.aic)
# Out:
# AIC:
# -54.611194085580856
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
model = ARIMA(log_Rolling_difference_b, order=(1, 0, 0))  
results_ARIMA = model.fit(trend= 'nc', disp=-1)  
plt.plot(log_Rolling_difference_b)
plt.plot(results_ARIMA.fittedvalues, color='red', label = 'p =2, q =6')
RSS =results_ARIMA.fittedvalues-log_Rolling_difference
RSS.dropna(inplace=True)
plt.title('RSS: %.4f'% sum(RSS**2))
plt.legend(loc='best')
print('AIC:')
print(results_ARIMA.aic)
# Out:
# AIC:
# -54.865438322652246
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):

# %%
from cryptocmd import CmcScraper
scraper2 = CmcScraper('BTC', '10-08-2015', '21-3-2018')
headers, data = scraper2.get_data()
scraper2.export_csv()
df_b = pd.read_csv('BTC_10-08-2015_21-03-2018.csv', dtype=str)

# %%
arima_d = ARIMA.ARIMA(endog=Y_train['XEM'], exog=X_train, order=[1,0,0])
arima_results_d = arima_d.fit()
print(arima_results_d.summary())

# Plotting the fitted values
plt.plot(np.arange(len(Y_train)), Y_train, color='purple', label='Actual')
plt.plot(np.arange(len(arima_results_d.fittedvalues)), arima_results_d.fittedvalues, color='green', label='Fitted Value')
plt.xlim((0, 400))
plt.title('ARIMAX Fitted Values')
plt.xlabel('Time')
plt.ylabel('Differenced Price')
plt.legend()
plt.show()
