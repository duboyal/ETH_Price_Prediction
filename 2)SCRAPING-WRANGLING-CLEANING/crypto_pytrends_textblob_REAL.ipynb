# %%
from pytrends.request import TrendReq

# Login to Google. Only need to run this once
pytrend = TrendReq()
# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
# keyword = 'cryptocurrency', cathegory = 16 (news), timeframe- limit range to 8 months to get daily data
pytrend.build_payload(kw_list=['bitcoin'], cat=16, timeframe='2017-11-15 2018-03-21')  

story_ggtrends_btc = pytrend.interest_over_time()
# Upsampling daily data to hourly data
story_ggtrends_btc = story_ggtrends_btc.resample('1d').pad().drop(['isPartial'], axis='columns')
story_ggtrends_btc.columns = ['SearchFrequency']
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# /Users/Alexandra/anaconda/lib/python3.6/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x11195c3c8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648             retries = retries.increment(method, url, error=e, _pool=self,
# --> 649                                         _stacktrace=sys.exc_info()[2])
#     650             retries.sleep()
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22bitcoin%22%2C+%22time%22%3A+%222017-11-15+2018-03-21%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+16%7D&property= (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x11195c3c8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-2b3ca4f6ced7> in <module>()
#       6 # Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
#       7 # keyword = 'cryptocurrency', cathegory = 16 (news), timeframe- limit range to 8 months to get daily data
# ----> 8 pytrend.build_payload(kw_list=['bitcoin'], cat=16, timeframe='2017-11-15 2018-03-21')
#       9
#      10 story_ggtrends_btc = pytrend.interest_over_time()
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/pytrends/request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     106         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     107         # get tokens
# --> 108         self._tokens()
#     109         return
#     110
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/pytrends/request.py in _tokens(self)
#     117             method=TrendReq.GET_METHOD,
#     118             params=self.token_payload,
# --> 119             trim_chars=4,
#     120         )['widgets']
#     121
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/pytrends/request.py in _get_data(self, url, method, trim_chars, **kwargs)
#      65             response = requests.post(url, **kwargs)
#      66         else:
# ---> 67             response = requests.get(url, **kwargs)
#      68
#      69         # check if the response contains json and throw an exception otherwise
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /Users/Alexandra/anaconda/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     500                 raise ProxyError(e, request=request)
#     501
# --> 502             raise ConnectionError(e, request=request)
#     503
#     504         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='trends.google.com', port=443): Max retries exceeded with url: /trends/api/explore?hl=en-US&tz=360&req=%7B%22comparisonItem%22%3A+%5B%7B%22keyword%22%3A+%22bitcoin%22%2C+%22time%22%3A+%222017-11-15+2018-03-21%22%2C+%22geo%22%3A+%22%22%7D%5D%2C+%22category%22%3A+16%7D&property= (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x11195c3c8>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))

# %%
import pandas as pd

# %%
ggtrends_btc = pd.read_csv('../1)DATA/google_trends/googletrends_bitcoin.csv')
ggtrends_btc.index = ggtrends_btc['date']
ggtrends_btc = ggtrends_btc['SearchFrequency'] 

#this is a series that can be put into matplotlib

# %%
len(ggtrends_btc)
# Out:
# 127

# %%
# OK I need to slice the data frame and then plot it. this is in blue
# I need to the plot the search frequency, this is in orange

# %%
import matplotlib.pyplot as plt
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize
import datetime
from pytrends.request import TrendReq
# %matplotlib inline

# %% [markdown]
# ##### following API worked
# pip install cryptocmd required

# %%
from cryptocmd import CmcScraper

# initialise scraper
scraper = CmcScraper('ETH', '15-11-2017', '21-3-2018')

# get data as list of list
headers, data = scraper.get_data()

# export the data to csv
scraper.export_csv()

# get dataframe for the data
df = scraper.get_dataframe()

# %%
df = pd.read_csv('other/ether.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'],infer_datetime_format=True)

# %%
df = df.sort_values('Date')

# %%
## df.iloc[-5:,:]

# %%
df = df.set_index("Date")

# %%
#df.Close.loc['2017-11-15':'2018-03-21'] for debugging

# %%
df_eth_price = df.Close.loc['2017-11-15':'2018-03-21']

# %%
#df_eth_price for debugging

# %%
type(df_eth_price) #not dataframe!!!!
# Out:
# pandas.core.series.Series

# %%
import matplotlib.pyplot as plt
#plt.plot(stuff)
plt.plot(df_eth_price)
plt.ylabel('some numbers')
plt.show()

# %%
#plt.plot(df_eth_price)
plt.plot(ggtrends_btc)
plt.ylabel('some numbers')
plt.show()

# %%
##Normalize the axes!

# %%
print(ggtrends_btc.max())
df_gg_norm = ggtrends_btc/(ggtrends_btc.max())
# Out:
# 100

# %%
print(df_eth_price.max())
df_eth_norm = df_eth_price/(df_eth_price.max())
# Out:
# 1396.42

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_eth_norm, alpha = 0.5)
plt.plot(df_gg_norm, alpha = 0.5)
plt.ylabel('some normie numbers')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ### Now TEXT BLOB

# %%
 df2 = pd.read_csv('LatestReddit/THIS/DONE/ETH/df_mega_eth.csv')

# %%
import datetime
import time

# %%
int_time = [int(item) for item in df2['timestamp']]

# %%
df2['timestamp'] = [datetime.datetime.fromtimestamp(item) for item in int_time]

# %%
from textblob import TextBlob

# %%
df2 = df2[df2.text.str.contains("[deleted]") == False]

# %%
df2['text'] = [str(item) for item in df2['text']]

# %%
textblob_objects = [TextBlob(item) for item in df2['text']]

# %%
sent_polarity = [item.sentiment.polarity for item in textblob_objects]

# %%
sent_subjectivity = [item.sentiment.polarity for item in textblob_objects]

# %%
df2['sent polarity'] = sent_polarity
df2['sent subjectivity'] = sent_subjectivity

# %%
df2['sent polarity'] =  df2['sent polarity'] +0.9765625
df2['sent subjectivity']= df2['sent subjectivity']+0.9765625

# %%
df2 = df2.set_index(df2['timestamp'])

# %%
df_mean = df2.groupby(df2['timestamp'].dt.normalize()).mean() #.dt.normalize()) hmmmm

# %%
df_mean['sent polarity'].min()
# Out:
# 0.86117788461538458

# %%
list1 = df_mean['sent polarity'].loc['2017-11-15':'2018-03-21']
df_mean['sent polarity'].max()
mean_list_norm = list1/(df_mean['sent polarity'].max())

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(mean_list_norm, alpha = 0.5)
#plt.plot(df_gg_norm, alpha = 0.5)
plt.ylabel('some normie numbers')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# #### following plot is plotting all 3 along a normalized axis

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(mean_list_norm, alpha = 0.5)
plt.plot(df_eth_norm, alpha = 0.5)
plt.plot(df_gg_norm, alpha = 0.5)
#plt.plot(df_gg_norm, alpha = 0.5)
plt.ylabel('some normie numbers')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ### Extra stuff from debugging

# %%
df_eth_price.head(1)
# Out:
# Date
# 2017-01-12    466.54
# Name: Close, dtype: float64

# %%
df_eth_price.tail(1)
# Out:
# Date
# 2018-12-03    699.83
# Name: Close, dtype: float64

# %%
print(story_ggtrends_btc.head(1),story_ggtrends_btc.tail(1))
# Out:
#             SearchFrequency
# date
# 2017-11-15               14             SearchFrequency
# date
# 2018-03-21               13
